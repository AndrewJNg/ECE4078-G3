# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# import time for timekeeping
import time

import os
from PIL import Image

# %%
# img = mpimg.imread('your_image.jpg')
# img = mpimg.imread('apple_2_label.png')
# img = mpimg.imread('image_1_label.png')

# img = mpimg.imread('3_label_pictures/apple/calib_10_apple_label.png')
# img = mpimg.imread('3_label_pictures/orange/2_orange_label.png')
# img = mpimg.imread('3_label_pictures/greenapple/image_33-removebg_label.png')
# img = mpimg.imread('3_label_pictures/orange/image_116-removebg_label.png')
# img = mpimg.imread('3_label_pictures/mango/image_65-removebg_label.png')
# img = mpimg.imread('3_label_pictures/capsicium/image_18-removebg_label.png')


val = 'image_62'
img = mpimg.imread("5_NN_Ready/images/" + val +".png")


# val = 'apple_14_nobg'
# img = mpimg.imread("2_removedbg/sample_all/" + val +".png")
print(img.shape)
# print(img.min()*255)
# print(img.max()*255)

imgplot = plt.imshow(img, cmap=plt.get_cmap('gray'))
plt.show()


img = mpimg.imread("5_NN_Ready/labels/" + val+'_label.png')

print(img.shape)
imgplot = plt.imshow(img, cmap=plt.get_cmap('gray'))
plt.show()

print('min = %d' %(img.min()*255))
print('label = %d' %(img.max()*255))
# Out:
# (480, 640, 3)
# (480, 640)
# min = 0
# label = 5
