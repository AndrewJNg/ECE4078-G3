# %%
import os
# from rembg import remove
from PIL import Image

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# import time for timekeeping
import time

# %%
def convertImages(input_directory , output_directory,label_value='0'):
    # input_directory = "./2_removedbg/"
    # output_directory = "./3_label_pictures/"
    # input_directory = "./milestone3\script\images"
    # output_directory = "./milestone3\script\labels"

    
    
    # create folder if it doesn't exist already
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)

        
        
    for filename in os.listdir(input_directory): #go through each of the images in the folder
        if filename.endswith(".png"):
            img_path = os.path.join(input_directory, filename)
            img = Image.open(img_path)
            # img = remove(img)
            img = img.convert("RGBA")

            datas = img.getdata()
            width, height = img.size

            # newImage = Image.new("L", (width, height))
            newImage = Image.new("LA", (width, height))
            # newImage.show()
            
            # newImage = Image.new(mode="RGB", (width, height))
            # print(newImage)
            # imgplot = plt.imshow(img, cmap=plt.get_cmap('gray'))

            for i, item in enumerate(datas):
                if item[3] == 0:  # Check if alpha (transparency) value is 0
                    # newImage.putpixel((i % width, i // width), (0)) # put as black and transparent
                    newImage.putpixel((i % width, i // width), (0,0)) # put as black and transparent
                elif item == [0,0,0]:
                    newImage.putpixel((i % width, i // width), (0,0)) # put as black and transparent
                    
                else:
                    # newImage.putpixel((i % width, i // width), (label_value))
                    newImage.putpixel((i % width, i // width), (label_value,255))

            # print(newImage.min())
            # print(newImage.max())
            # plt.show()
            base_filename, extension = os.path.splitext(filename)
            # print(extension)
            save_filename = os.path.join(output_directory, base_filename + "_label" + extension)
            newImage.save(save_filename, "PNG")
            print("Saved", save_filename)

    print("All images processed")

# %%
convertImages(input_directory = "./2_removedbg/apple/", output_directory = "./3_label_pictures/apple/",label_value = 1 )
# Out:
# Saved ./3_label_pictures/apple/calib_10_apple_label.png
# Saved ./3_label_pictures/apple/calib_11_apple_label.png
# Saved ./3_label_pictures/apple/calib_12_apple_label.png
# Saved ./3_label_pictures/apple/calib_13_apple_label.png
# Saved ./3_label_pictures/apple/calib_14_apple_label.png
# Saved ./3_label_pictures/apple/calib_15_apple_label.png
# Saved ./3_label_pictures/apple/calib_16_apple_label.png
# Saved ./3_label_pictures/apple/calib_17_apple_label.png
# Saved ./3_label_pictures/apple/calib_18_apple_label.png
# Saved ./3_label_pictures/apple/calib_1_apple_label.png
# Saved ./3_label_pictures/apple/calib_2_apple_label.png
# Saved ./3_label_pictures/apple/calib_3_apple_label.png
# Saved ./3_label_pictures/apple/calib_4_apple_label.png
# Saved ./3_label_pictures/apple/calib_5_apple_label.png
# Saved ./3_label_pictures/apple/calib_6_apple_label.png
# Saved ./3_label_pictures/apple/calib_7_apple_label.png
# Saved ./3_label_pictures/apple/calib_8_apple_label.png
# Saved ./3_label_pictures/apple/calib_9_apple_label.png
# Saved ./3_label_pictures/apple/img_10(1)_label.png
# Saved ./3_label_pictures/apple/img_10(2)_label.png
# Saved ./3_label_pictures/apple/img_10(3)_label.png
# Saved ./3_label_pictures/apple/img_10(4)_label.png
# Saved ./3_label_pictures/apple/img_10_label.png
# Saved ./3_label_pictures/apple/img_11_label.png
# Saved ./3_label_pictures/apple/img_12_label.png
# Saved ./3_label_pictures/apple/img_13_label.png
# Saved ./3_label_pictures/apple/img_14(1)_label.png
# Saved ./3_label_pictures/apple/img_14_label.png
# Saved ./3_label_pictures/apple/img_2_label.png
# Saved ./3_label_pictures/apple/img_3_label.png
# Saved ./3_label_pictures/apple/img_4(1)_label.png
# Saved ./3_label_pictures/apple/img_4(2)_label.png
# Saved ./3_label_pictures/apple/img_4(3)_label.png
# Saved ./3_label_pictures/apple/img_4(4)_label.png
# Saved ./3_label_pictures/apple/img_4_label.png
# Saved ./3_label_pictures/apple/img_5_label.png
# Saved ./3_label_pictures/apple/img_6_label.png
# Saved ./3_label_pictures/apple/img_7_label.png
# Saved ./3_label_pictures/apple/img_8_label.png
# Saved ./3_label_pictures/apple/img_9_label.png
# All images processed

# %%
convertImages(input_directory = "./2_removedbg/greenapple/", output_directory = "./3_label_pictures/greenapple/",label_value = 2 )
# Out:
# Saved ./3_label_pictures/greenapple/image_33_greenapple_label.png
# Saved ./3_label_pictures/greenapple/image_34_greenapple_label.png
# Saved ./3_label_pictures/greenapple/image_35_greenapple_label.png
# Saved ./3_label_pictures/greenapple/image_36_greenapple_label.png
# Saved ./3_label_pictures/greenapple/image_37_greenapple_label.png
# Saved ./3_label_pictures/greenapple/image_38_greenapple_label.png
# Saved ./3_label_pictures/greenapple/image_39_greenapple_label.png
# Saved ./3_label_pictures/greenapple/image_40_greenapple_label.png
# Saved ./3_label_pictures/greenapple/image_41_greenapple_label.png
# Saved ./3_label_pictures/greenapple/image_42_greenapple_label.png
# Saved ./3_label_pictures/greenapple/image_43_greenapple_label.png
# Saved ./3_label_pictures/greenapple/image_44_greenapple_label.png
# Saved ./3_label_pictures/greenapple/image_45_greenapple_label.png
# Saved ./3_label_pictures/greenapple/image_46_greenapple_label.png
# Saved ./3_label_pictures/greenapple/image_47_greenapple_label.png
# Saved ./3_label_pictures/greenapple/image_48_greenapple_label.png
# Saved ./3_label_pictures/greenapple/image_49_greenapple_label.png
# Saved ./3_label_pictures/greenapple/image_50_greenapple_label.png
# Saved ./3_label_pictures/greenapple/image_51_greenapple_label.png
# Saved ./3_label_pictures/greenapple/image_52_greenapple_label.png
# Saved ./3_label_pictures/greenapple/image_53_greenapple_label.png
# Saved ./3_label_pictures/greenapple/image_54_greenapple_label.png
# Saved ./3_label_pictures/greenapple/image_55_greenapple_label.png
# Saved ./3_label_pictures/greenapple/image_56_greenapple_label.png
# Saved ./3_label_pictures/greenapple/image_57_greenapple_label.png
# Saved ./3_label_pictures/greenapple/image_58_greenapple_label.png
# Saved ./3_label_pictures/greenapple/image_59_greenapple_label.png
# Saved ./3_label_pictures/greenapple/image_60_greenapple_label.png
# Saved ./3_label_pictures/greenapple/image_61_greenapple_label.png
# Saved ./3_label_pictures/greenapple/image_62_greenapple_label.png
# Saved ./3_label_pictures/greenapple/image_63_greenapple_label.png
# Saved ./3_label_pictures/greenapple/image_64_greenapple_label.png
# Saved ./3_label_pictures/greenapple/img_46_label.png
# Saved ./3_label_pictures/greenapple/img_47_label.png
# Saved ./3_label_pictures/greenapple/img_48_label.png
# Saved ./3_label_pictures/greenapple/img_49_label.png
# Saved ./3_label_pictures/greenapple/img_50_label.png
# Saved ./3_label_pictures/greenapple/img_51_label.png
# Saved ./3_label_pictures/greenapple/img_52_label.png
# Saved ./3_label_pictures/greenapple/img_53_label.png
# Saved ./3_label_pictures/greenapple/img_54_label.png
# Saved ./3_label_pictures/greenapple/img_55(1)_label.png
# Saved ./3_label_pictures/greenapple/img_55(2)_label.png
# Saved ./3_label_pictures/greenapple/img_55(3)_label.png
# Saved ./3_label_pictures/greenapple/img_55(4)_label.png
# Saved ./3_label_pictures/greenapple/img_55_label.png
# Saved ./3_label_pictures/greenapple/img_56_label.png
# Saved ./3_label_pictures/greenapple/img_57_label.png
# Saved ./3_label_pictures/greenapple/img_58_label.png
# Saved ./3_label_pictures/greenapple/img_59_label.png
# Saved ./3_label_pictures/greenapple/img_60(1)_label.png
# Saved ./3_label_pictures/greenapple/img_60(2)_label.png
# Saved ./3_label_pictures/greenapple/img_60(3)_label.png
# Saved ./3_label_pictures/greenapple/img_60_label.png
# Saved ./3_label_pictures/greenapple/img_61_label.png
# All images processed

# %%
convertImages(input_directory = "./2_removedbg/orange/", output_directory = "./3_label_pictures/orange/",label_value = 3 )
# Out:
# Saved ./3_label_pictures/orange/10_orange_label.png
# Saved ./3_label_pictures/orange/11_orange_label.png
# Saved ./3_label_pictures/orange/12_orange_label.png
# Saved ./3_label_pictures/orange/13_orange_label.png
# Saved ./3_label_pictures/orange/14_orange_label.png
# Saved ./3_label_pictures/orange/15_orange_label.png
# Saved ./3_label_pictures/orange/16_orange_label.png
# Saved ./3_label_pictures/orange/17_orange_label.png
# Saved ./3_label_pictures/orange/1_orange_label.png
# Saved ./3_label_pictures/orange/2_orange_label.png
# Saved ./3_label_pictures/orange/3_orange_label.png
# Saved ./3_label_pictures/orange/4_orange_label.png
# Saved ./3_label_pictures/orange/5_orange_label.png
# Saved ./3_label_pictures/orange/6_orange_label.png
# Saved ./3_label_pictures/orange/7_orange_label.png
# Saved ./3_label_pictures/orange/8_orange_label.png
# Saved ./3_label_pictures/orange/9_orange_label.png
# Saved ./3_label_pictures/orange/img_30(1)_label.png
# Saved ./3_label_pictures/orange/img_30(2)_label.png
# Saved ./3_label_pictures/orange/img_30(3)_label.png
# Saved ./3_label_pictures/orange/img_30_label.png
# Saved ./3_label_pictures/orange/img_31_label.png
# Saved ./3_label_pictures/orange/img_32_label.png
# Saved ./3_label_pictures/orange/img_33_label.png
# Saved ./3_label_pictures/orange/img_34(1)_label.png
# Saved ./3_label_pictures/orange/img_34(2)_label.png
# Saved ./3_label_pictures/orange/img_34(3)_label.png
# Saved ./3_label_pictures/orange/img_34(4)_label.png
# Saved ./3_label_pictures/orange/img_34_label.png
# Saved ./3_label_pictures/orange/img_35_label.png
# Saved ./3_label_pictures/orange/img_36_label.png
# Saved ./3_label_pictures/orange/img_37_label.png
# Saved ./3_label_pictures/orange/img_38_label.png
# Saved ./3_label_pictures/orange/img_39_label.png
# Saved ./3_label_pictures/orange/img_40_label.png
# Saved ./3_label_pictures/orange/img_41_label.png
# Saved ./3_label_pictures/orange/img_42_label.png
# Saved ./3_label_pictures/orange/img_43_label.png
# Saved ./3_label_pictures/orange/img_44_label.png
# Saved ./3_label_pictures/orange/img_45_label.png
# All images processed

# %%
# 
convertImages(input_directory = "./2_removedbg/mango/", output_directory = "./3_label_pictures/mango/",label_value = 4 )
# Out:
# Saved ./3_label_pictures/mango/image_100_mango_label.png
# Saved ./3_label_pictures/mango/image_101_mango_label.png
# Saved ./3_label_pictures/mango/image_102_mango_label.png
# Saved ./3_label_pictures/mango/image_103_mango_label.png
# Saved ./3_label_pictures/mango/image_104_mango_label.png
# Saved ./3_label_pictures/mango/image_105_mango_label.png
# Saved ./3_label_pictures/mango/image_106_mango_label.png
# Saved ./3_label_pictures/mango/image_107_mango_label.png
# Saved ./3_label_pictures/mango/image_108_mango_label.png
# Saved ./3_label_pictures/mango/image_109_mango_label.png
# Saved ./3_label_pictures/mango/image_110_mango_label.png
# Saved ./3_label_pictures/mango/image_111_mango_label.png
# Saved ./3_label_pictures/mango/image_112_mango_label.png
# Saved ./3_label_pictures/mango/image_113_mango_label.png
# Saved ./3_label_pictures/mango/image_114_mango_label.png
# Saved ./3_label_pictures/mango/image_115_mango_label.png
# Saved ./3_label_pictures/mango/image_65_mango_label.png
# Saved ./3_label_pictures/mango/image_66_mango_label.png
# Saved ./3_label_pictures/mango/image_67_mango_label.png
# Saved ./3_label_pictures/mango/image_68_mango_label.png
# Saved ./3_label_pictures/mango/image_69_mango_label.png
# Saved ./3_label_pictures/mango/image_70_mango_label.png
# Saved ./3_label_pictures/mango/image_71_mango_label.png
# Saved ./3_label_pictures/mango/image_72_mango_label.png
# Saved ./3_label_pictures/mango/image_73_mango_label.png
# Saved ./3_label_pictures/mango/image_74_mango_label.png
# Saved ./3_label_pictures/mango/image_75_mango_label.png
# Saved ./3_label_pictures/mango/image_76_mango_label.png
# Saved ./3_label_pictures/mango/image_77_mango_label.png
# Saved ./3_label_pictures/mango/image_78_mango_label.png
# Saved ./3_label_pictures/mango/image_79_mango_label.png
# Saved ./3_label_pictures/mango/image_80_mango_label.png
# Saved ./3_label_pictures/mango/image_81_mango_label.png
# Saved ./3_label_pictures/mango/image_82_mango_label.png
# Saved ./3_label_pictures/mango/image_83_mango_label.png
# Saved ./3_label_pictures/mango/image_84_mango_label.png
# Saved ./3_label_pictures/mango/image_85_mango_label.png
# Saved ./3_label_pictures/mango/image_86_mango_label.png
# Saved ./3_label_pictures/mango/image_87_mango_label.png
# Saved ./3_label_pictures/mango/image_88_mango_label.png
# Saved ./3_label_pictures/mango/image_89_mango_label.png
# Saved ./3_label_pictures/mango/image_90_mango_label.png
# Saved ./3_label_pictures/mango/image_91_mango_label.png
# Saved ./3_label_pictures/mango/image_92_mango_label.png
# Saved ./3_label_pictures/mango/image_93_mango_label.png
# Saved ./3_label_pictures/mango/image_94_mango_label.png
# Saved ./3_label_pictures/mango/image_95_mango_label.png
# Saved ./3_label_pictures/mango/image_96_mango_label.png
# Saved ./3_label_pictures/mango/image_97_mango_label.png
# Saved ./3_label_pictures/mango/image_98_mango_label.png
# Saved ./3_label_pictures/mango/image_99_mango_label.png
# Saved ./3_label_pictures/mango/img_62_label.png
# Saved ./3_label_pictures/mango/img_63_label.png
# Saved ./3_label_pictures/mango/img_64_label.png
# Saved ./3_label_pictures/mango/img_65_label.png
# Saved ./3_label_pictures/mango/img_66(1)_label.png
# Saved ./3_label_pictures/mango/img_66(2)_label.png
# Saved ./3_label_pictures/mango/img_66(3)_label.png
# Saved ./3_label_pictures/mango/img_66(4)_label.png
# Saved ./3_label_pictures/mango/img_66_label.png
# Saved ./3_label_pictures/mango/img_67_label.png
# Saved ./3_label_pictures/mango/img_68_label.png
# Saved ./3_label_pictures/mango/img_69_label.png
# Saved ./3_label_pictures/mango/img_70_label.png
# Saved ./3_label_pictures/mango/img_71_label.png
# Saved ./3_label_pictures/mango/img_72_label.png
# Saved ./3_label_pictures/mango/img_73_label.png
# Saved ./3_label_pictures/mango/img_74_label.png
# Saved ./3_label_pictures/mango/img_75_label.png
# Saved ./3_label_pictures/mango/img_76_label.png
# Saved ./3_label_pictures/mango/img_77_label.png
# Saved ./3_label_pictures/mango/img_78_label.png
# Saved ./3_label_pictures/mango/img_79_label.png
# Saved ./3_label_pictures/mango/img_80_label.png
# Saved ./3_label_pictures/mango/img_81_label.png
# Saved ./3_label_pictures/mango/img_82_label.png
# Saved ./3_label_pictures/mango/img_83_label.png
# Saved ./3_label_pictures/mango/img_84_label.png
# Saved ./3_label_pictures/mango/img_85_label.png
# Saved ./3_label_pictures/mango/img_86_label.png
# Saved ./3_label_pictures/mango/img_87_label.png
# Saved ./3_label_pictures/mango/img_88_label.png
# Saved ./3_label_pictures/mango/img_89_label.png
# Saved ./3_label_pictures/mango/img_90_label.png
# Saved ./3_label_pictures/mango/img_91_label.png
# Saved ./3_label_pictures/mango/img_92_label.png
# Saved ./3_label_pictures/mango/img_93_label.png
# Saved ./3_label_pictures/mango/img_94_label.png
# All images processed

# %%
convertImages(input_directory = "./2_removedbg/capsicium/" , output_directory = "./3_label_pictures/capsicium/",label_value = 5 )
# Out:
# Saved ./3_label_pictures/capsicium/calib_10_capsicium_label.png
# Saved ./3_label_pictures/capsicium/calib_11_capsicium_label.png
# Saved ./3_label_pictures/capsicium/calib_12_capsicium_label.png
# Saved ./3_label_pictures/capsicium/calib_13_capsicium_label.png
# Saved ./3_label_pictures/capsicium/calib_14_capsicium_label.png
# Saved ./3_label_pictures/capsicium/calib_15_capsicium_label.png
# Saved ./3_label_pictures/capsicium/calib_1_capsicium_label.png
# Saved ./3_label_pictures/capsicium/calib_2_capsicium_label.png
# Saved ./3_label_pictures/capsicium/calib_3_capsicium_label.png
# Saved ./3_label_pictures/capsicium/calib_4_capsicium_label.png
# Saved ./3_label_pictures/capsicium/calib_5_capsicium_label.png
# Saved ./3_label_pictures/capsicium/calib_6_capsicium_label.png
# Saved ./3_label_pictures/capsicium/calib_7_capsicium_label.png
# Saved ./3_label_pictures/capsicium/calib_8_capsicium_label.png
# Saved ./3_label_pictures/capsicium/calib_9_capsicium_label.png
# Saved ./3_label_pictures/capsicium/img_15_label.png
# Saved ./3_label_pictures/capsicium/img_16(1)_label.png
# Saved ./3_label_pictures/capsicium/img_16(2)_label.png
# Saved ./3_label_pictures/capsicium/img_16(3)_label.png
# Saved ./3_label_pictures/capsicium/img_16_label.png
# Saved ./3_label_pictures/capsicium/img_17_label.png
# Saved ./3_label_pictures/capsicium/img_18(1)_label.png
# Saved ./3_label_pictures/capsicium/img_18(2)_label.png
# Saved ./3_label_pictures/capsicium/img_18(3)_label.png
# Saved ./3_label_pictures/capsicium/img_18(4)_label.png
# Saved ./3_label_pictures/capsicium/img_18_label.png
# Saved ./3_label_pictures/capsicium/img_19_label.png
# Saved ./3_label_pictures/capsicium/img_20_label.png
# Saved ./3_label_pictures/capsicium/img_21_label.png
# Saved ./3_label_pictures/capsicium/img_22_label.png
# Saved ./3_label_pictures/capsicium/img_23_label.png
# Saved ./3_label_pictures/capsicium/img_24_label.png
# Saved ./3_label_pictures/capsicium/img_25_label.png
# Saved ./3_label_pictures/capsicium/img_26_label.png
# Saved ./3_label_pictures/capsicium/img_27(1)_label.png
# Saved ./3_label_pictures/capsicium/img_27(2)_label.png
# Saved ./3_label_pictures/capsicium/img_27(3)_label.png
# Saved ./3_label_pictures/capsicium/img_27_label.png
# Saved ./3_label_pictures/capsicium/img_28_label.png
# Saved ./3_label_pictures/capsicium/img_29_label.png
# All images processed
