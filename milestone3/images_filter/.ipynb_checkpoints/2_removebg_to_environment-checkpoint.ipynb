# %%
import os
from PIL import Image

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# import time for timekeeping
import time
import random
random.seed(1)

# %%
def convertImages(number_of_output, input_fruit, input_label,input_background ,output_image,output_label):
    start = time.time()
    
    # create output folder if it doesn't exist already
    if not os.path.exists(output_image):
        os.makedirs(output_image)
    if not os.path.exists(output_label):
        os.makedirs(output_label)
        
    ########################################################################################   
    
    input_bg_list = os.listdir(input_background)
    input_fruit_list = os.listdir(input_fruit)
    input_label_list = os.listdir(input_label)
    
    if(len(input_fruit_list) != len(input_label_list)):
        print("fruit" + str(len(input_fruit_list)))
        print("label" + str(len(input_label_list)))
    
    ## for loop for number of pictures to generate   
    for pic_num in range(number_of_output):

        # boolean term for 20% chance of getting two fruits in the same image
        bool_get_two_fruit = random.randrange(10) >=0
        bool_flip_image_horizontal = random.randrange(2)
        bool_flip_image_vertical = random.randrange(2)
        
        ## Generate random values to select pictures randomly
        # fruit & label shares the same index
        # print(len(input_fruit_list))
        index_fruit = random.randrange(1,len(input_fruit_list)-1)
        index_bg = random.randrange(1,len(input_bg_list)-1)

        # use the random value to pick from the list
        filename_bg = input_bg_list[index_bg]
        # print(index_fruit)
        filename_fruit = input_fruit_list[index_fruit]
        filename_label = input_label_list[index_fruit]
        
        # pick another fruit picture for double fruit
        if(bool_get_two_fruit == True):
            index_fruit = random.randrange(1,len(input_fruit_list)-1)
            # print(index_fruit)
            filename_fruit2 = input_fruit_list[index_fruit]
            filename_label2 = input_label_list[index_fruit]
            
            
    ######################################################################################## 
        ## open up the pictures
        if filename_bg.endswith(".png") or filename_bg.endswith('jpg'):
            img_path_bg = os.path.join(input_background, filename_bg)
            img_bg = Image.open(img_path_bg)
            newsize = (480, 640 )
            img_bg = img_bg.resize(newsize)
            
            if (bool_flip_image_horizontal):
                img_bg = img_bg.transpose(Image.FLIP_LEFT_RIGHT)
                            
            if (bool_flip_image_vertical):
                img_bg = img_bg.transpose(Image.FLIP_TOP_BOTTOM)
            
            img_bg = img_bg.convert("RGBA")

            img_path_fruit = os.path.join(input_fruit, filename_fruit)
            img_fruit = Image.open(img_path_fruit)
            img_fruit = img_fruit.convert("RGBA")

            img_path_label = os.path.join(input_label, filename_label)
            img_label = Image.open(img_path_label)
            img_label = img_label.convert("RGBA")
            
            # additional picture when there is a double fruit
            if(bool_get_two_fruit == True):
                img_path_fruit2 = os.path.join(input_fruit, filename_fruit2)
                img_fruit2 = Image.open(img_path_fruit2)
                img_fruit2 = img_fruit2.convert("RGBA")

                img_path_label2 = os.path.join(input_label, filename_label2)
                img_label2 = Image.open(img_path_label2)
                img_label2 = img_label2.convert("RGBA")
            
            # obtain image size to match
            width, height = img_bg.size
            img_label_output = Image.new(mode="L", size=(width, height))
            width  -= 80
            height -= 200
        ######################################################################################## 
            
            # set random values and coordinates
            scale = random.uniform(0.01, 2)
            ranx = random.randrange(-width/2,width/2)
            rany = random.randrange(-height/2,height/2)

            # apply random scaling to fruit image and label image
            img_fruit = img_fruit.resize((int(scale*640),int(scale*480)))
            img_label = img_label.resize((int(scale*640),int(scale*480)))

            # Pasting fruits using coordinate onto background, do the same for label on a blank background
            img_bg.paste(img_fruit, (ranx,rany), mask = img_fruit)
            
            
            img_label_output.paste(img_label, (ranx,rany), mask = img_label)
            
            
            if(bool_get_two_fruit == True):
                scale = random.uniform(0.01, 2)
                ranx = random.randrange(-width/2,width/2)
                rany = random.randrange(-height/2,height/2)
                
                img_fruit2 = img_fruit2.resize((int(scale*640),int(scale*480)))
                img_bg.paste(img_fruit2, (ranx,rany), mask = img_fruit2)
                
                img_label2 = img_label2.resize((int(scale*640),int(scale*480)))
                img_label_output.paste(img_label2, (ranx,rany), mask = img_label2)
                # min_val2, max_val2 = img_label_output.getextrema()
                # print(max_val2)
                
                
            img_bg = img_bg.convert("RGB")
            img_label_output = img_label_output.convert("L")
            min_val, max_val = img_label_output.getextrema()
            
            # if(bool_get_two_fruit == True):
                # min_val2, max_val2 = img_label2.getextrema()
            if((max_val)<=5):
            
                
            # if(bool_get_two_fruit == True):
            #     max(img_label_output)
            #     max(img_label2)
            
            # img = img_label_output.getdata()
            # width, height = img.size
            
            # for i, item in enumerate(datas):
            #     for 
            #     if item[0] >  :
            #         newImage.putpixel((i % width, i// width),0)
                    

        ######################################################################################## 
            ## save the pictures into the directed folder
                extension = ".png"
                offset = 8957
                save_filename_fruit = os.path.join(output_image, "image_"  + str(pic_num+offset)+ extension)
                img_bg.save(save_filename_fruit, "PNG")

                save_filename_label = os.path.join(output_label, "image_"  + str(pic_num+offset) + "_label"+ extension)
                img_label_output.save(save_filename_label, "PNG")

                if((pic_num%100==0) or pic_num==(number_of_output-1)):
                    end = time.time()
                    print("Saved", save_filename_fruit,",  Saved", save_filename_label,",  time taken: " , round((end - start) / 60,3), "min") # time in minutes
            # else:
                
#                 extension = ".png"
#                 save_filename_fruit = os.path.join(output_image, "image_"  + str(pic_num)+ extension)
#                 img_bg.save(save_filename_fruit, "PNG")

#                 save_filename_label = os.path.join(output_label, "image_"  + str(pic_num) + "_label"+ extension)
#                 img_label_output.save(save_filename_label, "PNG")

#                 if((pic_num%100==0) or pic_num==(number_of_output-1)):
#                     end = time.time()
#                     print("Saved", save_filename_fruit,",  Saved", save_filename_label,",  time taken: " , round((end - start) / 60,3), "min") # time in minutes

# %%
start = time.time()

convertImages(number_of_output =30000, 
              input_fruit      = "./2_removedbg/sample_all/", 
              input_label      ="./3_label_pictures/sample_all/", #"./2_removedbg/apple/", #  
              input_background = "./4_arena_pics/" ,
              output_image     = "5_NN_Ready/images",
              output_label     = "5_NN_Ready/labels")

end = time.time()
print((end - start) / 60) # time in minutes
# Out:
# Saved 5_NN_Ready/images\image_8957.png ,  Saved 5_NN_Ready/labels\image_8957_label.png ,  time taken:  0.002 min
# Saved 5_NN_Ready/images\image_9157.png ,  Saved 5_NN_Ready/labels\image_9157_label.png ,  time taken:  0.378 min
# Saved 5_NN_Ready/images\image_9257.png ,  Saved 5_NN_Ready/labels\image_9257_label.png ,  time taken:  0.564 min
# Saved 5_NN_Ready/images\image_9357.png ,  Saved 5_NN_Ready/labels\image_9357_label.png ,  time taken:  0.756 min
# Saved 5_NN_Ready/images\image_9457.png ,  Saved 5_NN_Ready/labels\image_9457_label.png ,  time taken:  0.94 min
# Saved 5_NN_Ready/images\image_9557.png ,  Saved 5_NN_Ready/labels\image_9557_label.png ,  time taken:  1.135 min
# Saved 5_NN_Ready/images\image_9657.png ,  Saved 5_NN_Ready/labels\image_9657_label.png ,  time taken:  1.326 min
# Saved 5_NN_Ready/images\image_9757.png ,  Saved 5_NN_Ready/labels\image_9757_label.png ,  time taken:  1.519 min
# Saved 5_NN_Ready/images\image_9857.png ,  Saved 5_NN_Ready/labels\image_9857_label.png ,  time taken:  1.714 min
# Saved 5_NN_Ready/images\image_9957.png ,  Saved 5_NN_Ready/labels\image_9957_label.png ,  time taken:  1.916 min
# Saved 5_NN_Ready/images\image_10057.png ,  Saved 5_NN_Ready/labels\image_10057_label.png ,  time taken:  2.102 min
# Saved 5_NN_Ready/images\image_10157.png ,  Saved 5_NN_Ready/labels\image_10157_label.png ,  time taken:  2.295 min
# Saved 5_NN_Ready/images\image_10257.png ,  Saved 5_NN_Ready/labels\image_10257_label.png ,  time taken:  2.495 min
# Saved 5_NN_Ready/images\image_10357.png ,  Saved 5_NN_Ready/labels\image_10357_label.png ,  time taken:  2.692 min
# Saved 5_NN_Ready/images\image_10457.png ,  Saved 5_NN_Ready/labels\image_10457_label.png ,  time taken:  2.89 min
# Saved 5_NN_Ready/images\image_10657.png ,  Saved 5_NN_Ready/labels\image_10657_label.png ,  time taken:  3.291 min
# Saved 5_NN_Ready/images\image_10757.png ,  Saved 5_NN_Ready/labels\image_10757_label.png ,  time taken:  3.484 min
# Saved 5_NN_Ready/images\image_10857.png ,  Saved 5_NN_Ready/labels\image_10857_label.png ,  time taken:  3.681 min
# Saved 5_NN_Ready/images\image_10957.png ,  Saved 5_NN_Ready/labels\image_10957_label.png ,  time taken:  3.875 min
# Saved 5_NN_Ready/images\image_11057.png ,  Saved 5_NN_Ready/labels\image_11057_label.png ,  time taken:  4.063 min
# Saved 5_NN_Ready/images\image_11157.png ,  Saved 5_NN_Ready/labels\image_11157_label.png ,  time taken:  4.245 min
# Saved 5_NN_Ready/images\image_11257.png ,  Saved 5_NN_Ready/labels\image_11257_label.png ,  time taken:  4.442 min
# Saved 5_NN_Ready/images\image_11357.png ,  Saved 5_NN_Ready/labels\image_11357_label.png ,  time taken:  4.648 min
# Saved 5_NN_Ready/images\image_11457.png ,  Saved 5_NN_Ready/labels\image_11457_label.png ,  time taken:  4.841 min
# Saved 5_NN_Ready/images\image_11657.png ,  Saved 5_NN_Ready/labels\image_11657_label.png ,  time taken:  5.221 min
# Saved 5_NN_Ready/images\image_11757.png ,  Saved 5_NN_Ready/labels\image_11757_label.png ,  time taken:  5.425 min
# Saved 5_NN_Ready/images\image_11857.png ,  Saved 5_NN_Ready/labels\image_11857_label.png ,  time taken:  5.623 min
# Saved 5_NN_Ready/images\image_11957.png ,  Saved 5_NN_Ready/labels\image_11957_label.png ,  time taken:  5.82 min
# Saved 5_NN_Ready/images\image_12057.png ,  Saved 5_NN_Ready/labels\image_12057_label.png ,  time taken:  6.021 min
# Saved 5_NN_Ready/images\image_12257.png ,  Saved 5_NN_Ready/labels\image_12257_label.png ,  time taken:  6.428 min
# Saved 5_NN_Ready/images\image_12357.png ,  Saved 5_NN_Ready/labels\image_12357_label.png ,  time taken:  6.632 min
# Saved 5_NN_Ready/images\image_12457.png ,  Saved 5_NN_Ready/labels\image_12457_label.png ,  time taken:  6.837 min
# Saved 5_NN_Ready/images\image_12557.png ,  Saved 5_NN_Ready/labels\image_12557_label.png ,  time taken:  7.042 min
# Saved 5_NN_Ready/images\image_12657.png ,  Saved 5_NN_Ready/labels\image_12657_label.png ,  time taken:  7.231 min
# Saved 5_NN_Ready/images\image_12757.png ,  Saved 5_NN_Ready/labels\image_12757_label.png ,  time taken:  7.434 min
# Saved 5_NN_Ready/images\image_12857.png ,  Saved 5_NN_Ready/labels\image_12857_label.png ,  time taken:  7.63 min
# Saved 5_NN_Ready/images\image_12957.png ,  Saved 5_NN_Ready/labels\image_12957_label.png ,  time taken:  7.827 min
# Saved 5_NN_Ready/images\image_13057.png ,  Saved 5_NN_Ready/labels\image_13057_label.png ,  time taken:  8.028 min
# Saved 5_NN_Ready/images\image_13157.png ,  Saved 5_NN_Ready/labels\image_13157_label.png ,  time taken:  8.218 min
# Saved 5_NN_Ready/images\image_13257.png ,  Saved 5_NN_Ready/labels\image_13257_label.png ,  time taken:  8.417 min
# Saved 5_NN_Ready/images\image_13357.png ,  Saved 5_NN_Ready/labels\image_13357_label.png ,  time taken:  8.612 min
# Saved 5_NN_Ready/images\image_13457.png ,  Saved 5_NN_Ready/labels\image_13457_label.png ,  time taken:  8.81 min
# Saved 5_NN_Ready/images\image_13557.png ,  Saved 5_NN_Ready/labels\image_13557_label.png ,  time taken:  9.01 min
# Saved 5_NN_Ready/images\image_13657.png ,  Saved 5_NN_Ready/labels\image_13657_label.png ,  time taken:  9.212 min
# Saved 5_NN_Ready/images\image_13757.png ,  Saved 5_NN_Ready/labels\image_13757_label.png ,  time taken:  9.415 min
# Saved 5_NN_Ready/images\image_13857.png ,  Saved 5_NN_Ready/labels\image_13857_label.png ,  time taken:  9.621 min
# Saved 5_NN_Ready/images\image_13957.png ,  Saved 5_NN_Ready/labels\image_13957_label.png ,  time taken:  9.819 min
# Saved 5_NN_Ready/images\image_14057.png ,  Saved 5_NN_Ready/labels\image_14057_label.png ,  time taken:  10.029 min
# Saved 5_NN_Ready/images\image_14157.png ,  Saved 5_NN_Ready/labels\image_14157_label.png ,  time taken:  10.23 min
# Saved 5_NN_Ready/images\image_14257.png ,  Saved 5_NN_Ready/labels\image_14257_label.png ,  time taken:  10.443 min
# Saved 5_NN_Ready/images\image_14357.png ,  Saved 5_NN_Ready/labels\image_14357_label.png ,  time taken:  10.642 min
# Saved 5_NN_Ready/images\image_14457.png ,  Saved 5_NN_Ready/labels\image_14457_label.png ,  time taken:  10.843 min
# Saved 5_NN_Ready/images\image_14557.png ,  Saved 5_NN_Ready/labels\image_14557_label.png ,  time taken:  11.031 min
# Saved 5_NN_Ready/images\image_14657.png ,  Saved 5_NN_Ready/labels\image_14657_label.png ,  time taken:  11.222 min
# Saved 5_NN_Ready/images\image_14857.png ,  Saved 5_NN_Ready/labels\image_14857_label.png ,  time taken:  11.631 min
# Saved 5_NN_Ready/images\image_14957.png ,  Saved 5_NN_Ready/labels\image_14957_label.png ,  time taken:  11.831 min
# Saved 5_NN_Ready/images\image_15057.png ,  Saved 5_NN_Ready/labels\image_15057_label.png ,  time taken:  12.028 min
# Saved 5_NN_Ready/images\image_15257.png ,  Saved 5_NN_Ready/labels\image_15257_label.png ,  time taken:  12.427 min
# Saved 5_NN_Ready/images\image_15357.png ,  Saved 5_NN_Ready/labels\image_15357_label.png ,  time taken:  12.624 min
# Saved 5_NN_Ready/images\image_15457.png ,  Saved 5_NN_Ready/labels\image_15457_label.png ,  time taken:  12.823 min
# Saved 5_NN_Ready/images\image_15557.png ,  Saved 5_NN_Ready/labels\image_15557_label.png ,  time taken:  13.016 min
# Saved 5_NN_Ready/images\image_15657.png ,  Saved 5_NN_Ready/labels\image_15657_label.png ,  time taken:  13.21 min
# Saved 5_NN_Ready/images\image_15757.png ,  Saved 5_NN_Ready/labels\image_15757_label.png ,  time taken:  13.409 min
# Saved 5_NN_Ready/images\image_15857.png ,  Saved 5_NN_Ready/labels\image_15857_label.png ,  time taken:  13.606 min
# Saved 5_NN_Ready/images\image_16057.png ,  Saved 5_NN_Ready/labels\image_16057_label.png ,  time taken:  14.001 min
# Saved 5_NN_Ready/images\image_16157.png ,  Saved 5_NN_Ready/labels\image_16157_label.png ,  time taken:  14.192 min
# Saved 5_NN_Ready/images\image_16257.png ,  Saved 5_NN_Ready/labels\image_16257_label.png ,  time taken:  14.385 min
# Saved 5_NN_Ready/images\image_16357.png ,  Saved 5_NN_Ready/labels\image_16357_label.png ,  time taken:  14.589 min
# Saved 5_NN_Ready/images\image_16457.png ,  Saved 5_NN_Ready/labels\image_16457_label.png ,  time taken:  14.78 min
# Saved 5_NN_Ready/images\image_16557.png ,  Saved 5_NN_Ready/labels\image_16557_label.png ,  time taken:  14.977 min
# Saved 5_NN_Ready/images\image_16657.png ,  Saved 5_NN_Ready/labels\image_16657_label.png ,  time taken:  15.176 min
# Saved 5_NN_Ready/images\image_16757.png ,  Saved 5_NN_Ready/labels\image_16757_label.png ,  time taken:  15.372 min
# Saved 5_NN_Ready/images\image_16857.png ,  Saved 5_NN_Ready/labels\image_16857_label.png ,  time taken:  15.57 min
# Saved 5_NN_Ready/images\image_16957.png ,  Saved 5_NN_Ready/labels\image_16957_label.png ,  time taken:  15.764 min
# Saved 5_NN_Ready/images\image_17057.png ,  Saved 5_NN_Ready/labels\image_17057_label.png ,  time taken:  15.958 min
# Saved 5_NN_Ready/images\image_17157.png ,  Saved 5_NN_Ready/labels\image_17157_label.png ,  time taken:  16.149 min
# Saved 5_NN_Ready/images\image_17357.png ,  Saved 5_NN_Ready/labels\image_17357_label.png ,  time taken:  16.529 min
# Saved 5_NN_Ready/images\image_17457.png ,  Saved 5_NN_Ready/labels\image_17457_label.png ,  time taken:  16.722 min
# Saved 5_NN_Ready/images\image_17557.png ,  Saved 5_NN_Ready/labels\image_17557_label.png ,  time taken:  16.916 min
# Saved 5_NN_Ready/images\image_17657.png ,  Saved 5_NN_Ready/labels\image_17657_label.png ,  time taken:  17.111 min
# Saved 5_NN_Ready/images\image_17757.png ,  Saved 5_NN_Ready/labels\image_17757_label.png ,  time taken:  17.306 min
# Saved 5_NN_Ready/images\image_17857.png ,  Saved 5_NN_Ready/labels\image_17857_label.png ,  time taken:  17.499 min
# Saved 5_NN_Ready/images\image_17957.png ,  Saved 5_NN_Ready/labels\image_17957_label.png ,  time taken:  17.685 min
# Saved 5_NN_Ready/images\image_18057.png ,  Saved 5_NN_Ready/labels\image_18057_label.png ,  time taken:  17.875 min
# Saved 5_NN_Ready/images\image_18157.png ,  Saved 5_NN_Ready/labels\image_18157_label.png ,  time taken:  18.066 min
# Saved 5_NN_Ready/images\image_18257.png ,  Saved 5_NN_Ready/labels\image_18257_label.png ,  time taken:  18.254 min
# Saved 5_NN_Ready/images\image_18357.png ,  Saved 5_NN_Ready/labels\image_18357_label.png ,  time taken:  18.435 min
# Saved 5_NN_Ready/images\image_18457.png ,  Saved 5_NN_Ready/labels\image_18457_label.png ,  time taken:  18.626 min
# Saved 5_NN_Ready/images\image_18557.png ,  Saved 5_NN_Ready/labels\image_18557_label.png ,  time taken:  18.821 min
# Saved 5_NN_Ready/images\image_18657.png ,  Saved 5_NN_Ready/labels\image_18657_label.png ,  time taken:  19.017 min
# Saved 5_NN_Ready/images\image_18757.png ,  Saved 5_NN_Ready/labels\image_18757_label.png ,  time taken:  19.217 min
# Saved 5_NN_Ready/images\image_18857.png ,  Saved 5_NN_Ready/labels\image_18857_label.png ,  time taken:  19.402 min
# Saved 5_NN_Ready/images\image_18957.png ,  Saved 5_NN_Ready/labels\image_18957_label.png ,  time taken:  19.599 min
# Saved 5_NN_Ready/images\image_19057.png ,  Saved 5_NN_Ready/labels\image_19057_label.png ,  time taken:  19.795 min
# Saved 5_NN_Ready/images\image_19157.png ,  Saved 5_NN_Ready/labels\image_19157_label.png ,  time taken:  19.993 min
# Saved 5_NN_Ready/images\image_19257.png ,  Saved 5_NN_Ready/labels\image_19257_label.png ,  time taken:  20.188 min
# Saved 5_NN_Ready/images\image_19357.png ,  Saved 5_NN_Ready/labels\image_19357_label.png ,  time taken:  20.376 min
# Saved 5_NN_Ready/images\image_19457.png ,  Saved 5_NN_Ready/labels\image_19457_label.png ,  time taken:  20.57 min
# Saved 5_NN_Ready/images\image_19557.png ,  Saved 5_NN_Ready/labels\image_19557_label.png ,  time taken:  20.763 min
# Saved 5_NN_Ready/images\image_19657.png ,  Saved 5_NN_Ready/labels\image_19657_label.png ,  time taken:  20.963 min
# Saved 5_NN_Ready/images\image_19757.png ,  Saved 5_NN_Ready/labels\image_19757_label.png ,  time taken:  21.158 min
# Saved 5_NN_Ready/images\image_19857.png ,  Saved 5_NN_Ready/labels\image_19857_label.png ,  time taken:  21.352 min
# Saved 5_NN_Ready/images\image_19957.png ,  Saved 5_NN_Ready/labels\image_19957_label.png ,  time taken:  21.547 min
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File D:\Monash_Apps\Anaconda\lib\site-packages\PIL\ImageFile.py:518, in _save(im, fp, tile, bufsize)
#     517 try:
# --> 518     fh = fp.fileno()
#     519     fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 start = time.time()
# ----> 3 convertImages(number_of_output =30000,
#       4               input_fruit      = "./2_removedbg/sample_all/",
#       5               input_label      ="./3_label_pictures/sample_all/", #"./2_removedbg/apple/", #
#       6               input_background = "./4_arena_pics/" ,
#       7               output_image     = "5_NN_Ready/images",
#       8               output_label     = "5_NN_Ready/labels")
#      10 end = time.time()
#      11 print((end - start) / 60)
#
# Cell In[2], line 146, in convertImages(number_of_output, input_fruit, input_label, input_background, output_image, output_label)
#     144 offset = 8957
#     145 save_filename_fruit = os.path.join(output_image, "image_"  + str(pic_num+offset)+ extension)
# --> 146 img_bg.save(save_filename_fruit, "PNG")
#     148 save_filename_label = os.path.join(output_label, "image_"  + str(pic_num+offset) + "_label"+ extension)
#     149 img_label_output.save(save_filename_label, "PNG")
#
# File D:\Monash_Apps\Anaconda\lib\site-packages\PIL\Image.py:2431, in Image.save(self, fp, format, **params)
#    2428         fp = builtins.open(filename, "w+b")
#    2430 try:
# -> 2431     save_handler(self, fp, filename)
#    2432 except Exception:
#    2433     if open_fp:
#
# File D:\Monash_Apps\Anaconda\lib\site-packages\PIL\PngImagePlugin.py:1420, in _save(im, fp, filename, chunk, save_all)
#    1418     _write_multiple_frames(im, fp, chunk, rawmode, default_image, append_images)
#    1419 else:
# -> 1420     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#    1422 if info:
#    1423     for info_chunk in info.chunks:
#
# File D:\Monash_Apps\Anaconda\lib\site-packages\PIL\ImageFile.py:522, in _save(im, fp, tile, bufsize)
#     520     _encode_tile(im, fp, tile, bufsize, fh)
#     521 except (AttributeError, io.UnsupportedOperation) as exc:
# --> 522     _encode_tile(im, fp, tile, bufsize, None, exc)
#     523 if hasattr(fp, "flush"):
#     524     fp.flush()
#
# File D:\Monash_Apps\Anaconda\lib\site-packages\PIL\ImageFile.py:541, in _encode_tile(im, fp, tile, bufsize, fh, exc)
#     538 if exc:
#     539     # compress to Python file-compatible object
#     540     while True:
# --> 541         l, s, d = encoder.encode(bufsize)
#     542         fp.write(d)
#     543         if s:
#
# KeyboardInterrupt:
